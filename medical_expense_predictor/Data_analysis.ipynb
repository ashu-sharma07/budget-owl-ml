# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('insurance.csv')
df
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
df.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# Categorical Variables

for i in df:
    if df[i].dtype==object:
        print(i,end=" ")
        print("=>   Unique Values:-", end=" ")
        print(df[i].unique(),end="\t")
        print(f"Dtype of {i}:-",end=" ")
        print(df[i].dtype)
        
#Numerical files

for i in df:
    if df[i].dtype!=object:
        print(i,end=" ")
        print(f"Dtype of {i}:-",end=" ")
        print(df[i].dtype)
# Out:
# sex =>   Unique Values:- ['female' 'male']	Dtype of sex:- object
# smoker =>   Unique Values:- ['yes' 'no']	Dtype of smoker:- object
# region =>   Unique Values:- ['southwest' 'southeast' 'northwest' 'northeast']	Dtype of region:- object
# age Dtype of age:- int64
# bmi Dtype of bmi:- float64
# children Dtype of children:- int64
# charges Dtype of charges:- float64

# %%
#Na values
# make a list of the variables that contain missing values
vars_with_na = [var for var in df.columns if df[var].isnull().sum() > 0]

# determine percentage of missing values (expressed as decimals)
# and display the result ordered by % of missin data

df[vars_with_na].isnull().mean().sort_values(ascending=False)
# Out:
# Series([], dtype: float64)

# %% [markdown]
# No NA values are present. Pheww!!!!

# %%
# i just printed all the unique values with their share just to get an idea about how the data is distributed:)
for var in df:
    print(df[var].value_counts(normalize=True)*100)
# Out:
# 18    5.156951
# 19    5.082212
# 50    2.167414
# 51    2.167414
# 47    2.167414
# 46    2.167414
# 45    2.167414
# 20    2.167414
# 48    2.167414
# 52    2.167414
# 22    2.092676
# 49    2.092676
# 54    2.092676
# 53    2.092676
# 21    2.092676
# 26    2.092676
# 24    2.092676
# 25    2.092676
# 28    2.092676
# 27    2.092676
# 23    2.092676
# 43    2.017937
# 29    2.017937
# 30    2.017937
# 41    2.017937
# 42    2.017937
# 44    2.017937
# 31    2.017937
# 40    2.017937
# 32    1.943199
# 33    1.943199
# 56    1.943199
# 34    1.943199
# 55    1.943199
# 57    1.943199
# 37    1.868460
# 59    1.868460
# 58    1.868460
# 36    1.868460
# 38    1.868460
# 35    1.868460
# 39    1.868460
# 61    1.718984
# 60    1.718984
# 63    1.718984
# 62    1.718984
# 64    1.644245
# Name: age, dtype: float64
# male      50.523169
# female    49.476831
# Name: sex, dtype: float64
# 32.300    0.971599
# 28.310    0.672646
# 30.495    0.597907
# 30.875    0.597907
# ...

# %%
for var in df:
    (df[var].hist(bins=50))
    plt.ylabel('No of Students')
    plt.xlabel('Monthly Expense')
    plt.show()

# %% [markdown]
# We observe that the data distribution is not skewed(in case of numerical categories).So no data needs to be transformed.
